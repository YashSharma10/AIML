# %% [markdown]
# <a href="https://colab.research.google.com/github/YashSharma10/AIML/blob/main/18sept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
b = np.array([1.1,2.4,3,4])
print(b)
# Out:
# [1.1 2.4 3.  4. ]

# %%
c = a + b
print(c)
# Out:
# [2.1 4.4 6.  8. ]

# %%
c.sort()
print(c)
# Out:
# [2.1 4.4 6.  8. ]

# %%
d = np.array([(1,2,3) , (4,5,6)])
print(d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
e = np.array([(12,34,55) , (41,25,46)])
print(e)
# Out:
# [[12 34 55]
#  [41 25 46]]

# %%
f = d + e
print(f)
# Out:
# [[13 36 58]
#  [45 30 52]]

# %%
g = np.zeros((3,3))
print(g)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
h = np.arange(10,25,5)
print(h)
# Out:
# [10 15 20]

# %%
i = np.linspace(0,2,9)
print(i)
# Out:
# [0.   0.25 0.5  0.75 1.   1.25 1.5  1.75 2.  ]

# %%
j = np.full((2,2),7)
print(j)
# Out:
# [[7 7]
#  [7 7]]

# %%
k = np.eye(2) # identity matrix
print(k)
# Out:
# [[1. 0.]
#  [0. 1.]]

# %%
l = np.random.random((2,2))
print(l)
# Out:
# [[0.97278825 0.91732758]
#  [0.29261521 0.02544127]]

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
 s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])
 print(s)
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
data = {'Country': ['Belgium', 'India', 'Brazil'],
 'Capital': ['Brussels', 'New Delhi', 'Brasília'],
 'Population': [11190846, 1303171035, 207847528]}
print(data)
# Out:
# {'Country': ['Belgium', 'India', 'Brazil'], 'Capital': ['Brussels', 'New Delhi', 'Brasília'], 'Population': [11190846, 1303171035, 207847528]}

# %%
df = pd.DataFrame(data,
 columns=['Country', 'Capital', 'Population'])
print(df)
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
>>> s['b']
# Out:
# -5

# %%
df[1:]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasília   207847528

# %%
df.iloc[[0],[0]]
# Out:
#    Country
# 0  Belgium

# %%
s.drop(['a', 'c'])
# Out:
# b   -5
# d    4
# dtype: int64

# %%
df.drop('Country', axis=1)
# Out:
#      Capital  Population
# 0   Brussels    11190846
# 1  New Delhi  1303171035
# 2   Brasília   207847528

# %%
df.sort_index()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df.sort_values(by='Country')
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 2   Brazil   Brasília   207847528
# 1    India  New Delhi  1303171035

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     3 non-null      object
#  1   Capital     3 non-null      object
#  2   Population  3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
f = lambda x: x*2
df.apply(f)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels    22381692
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasíliaBrasília   415695056

# %% [markdown]
# # EDA Cars

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# Importing the dataset
df=pd.read_excel('EDA Cars-1.xlsx')
df.head()
# Out:
#    INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.24250             No   F    Bachelors  Blue Collar
# 1      2   50815.44531             No   M  High School          NaN
# 2      3   62977.82416            NaN   F    Bachelors     Clerical
# 3      4   77099.96624             No   F          NaN       Lawyer
# 4      5  130794.57420             No   M  High School          NaN
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private            NaN          SUV      1.0  Texas
# 3    15.415676         NaN        18300.0   Sports Car     11.0  Texas
# 4          NaN  Commercial        28340.0  Panel Truck     10.0  Texas
#
#    POSTAL CODE
# 0      42420.0
# 1      42420.0
# 2      42420.0
# 3      42420.0
# 4      42420.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          260 non-null    float64
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   278 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 30.9+ KB

# %%
df["POSTAL CODE"]=pd.Categorical(df['POSTAL CODE'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          260 non-null    float64
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   278 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    category
# dtypes: category(1), float64(4), int64(1), object(7)
# memory usage: 29.2+ KB

# %%
dups=df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 14

# %%
df.drop_duplicates(inplace=True)

# %%
dups=df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %%
df.shape
# Out:
# (289, 13)

# %%
df.boxplot(column = ['INCOME','TRAVEL TIME'])
plt.show()

# %%
df.boxplot(column=['TRAVEL TIME'])
plt.show()

# %%
df.boxplot(column=['CAR AGE'])
plt.show()

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
lrincome,urincome=remove_outlier(df['INCOME'])
df['INCOME']=np.where(df['INCOME']>urincome,urincome,df['INCOME'])
df['INCOME']=np.where(df['INCOME']<lrincome,lrincome,df['INCOME'])


lrtravel,urtravel=remove_outlier(df['TRAVEL TIME'])
df['TRAVEL TIME']=np.where(df['TRAVEL TIME']>urtravel,urtravel,df['TRAVEL TIME'])
df['TRAVEL TIME']=np.where(df['TRAVEL TIME']<lrtravel,lrtravel,df['TRAVEL TIME'])

lrmiles,urmiles=remove_outlier(df['MILES CLOCKED'])
df['MILES CLOCKED']=np.where(df['MILES CLOCKED']>urmiles,urmiles,df['MILES CLOCKED'])
df['MILES CLOCKED']=np.where(df['MILES CLOCKED']<lrmiles,lrmiles,df['MILES CLOCKED'])

df.shape
# Out:
# (289, 13)

# %%
df.boxplot(column=['INCOME'])
plt.show()

# %%
df.boxplot(column=['TRAVEL TIME'])
plt.show()

# %%
df.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
median1=df["INCOME"].median()
median2=df["TRAVEL TIME"].median()
median3=df["MILES CLOCKED"].median()
median4=df["CAR AGE"].median()

# %%
df["INCOME"].replace(np.nan,median1,inplace=True)
df["TRAVEL TIME"].replace(np.nan,median2,inplace=True)
df["MILES CLOCKED"].replace(np.nan,median3,inplace=True)
df["CAR AGE"].replace(np.nan,median4,inplace=True)

# %%
mode1=df["SEX"].mode().values[0]
mode2=df["MARITAL STATUS"].mode().values[0]
mode3=df["EDUCATION"].mode().values[0]
mode4=df["JOB"].mode().values[0]
mode5=df["USE"].mode().values[0]
mode6=df['CITY'].mode().values[0]
mode7=df["CAR TYPE"].mode().values[0]
mode8=df["POSTAL CODE"].mode().values[0]

df["SEX"]=df["SEX"].replace(np.nan,mode1)
df["MARITAL STATUS"]= df["MARITAL STATUS"].replace(np.nan,mode2)
df["EDUCATION"]=df["EDUCATION"].replace(np.nan,mode3)
df["JOB"]=df["JOB"].replace(np.nan,mode4)
df["USE"]=df["USE"].replace(np.nan,mode5)
df["CAR TYPE"]=df["CAR TYPE"].replace(np.nan,mode7)
df['CITY']=df['CITY'].replace(np.nan,mode6)
df['POSTAL CODE']=df['POSTAL CODE'].replace(np.nan,mode8)

# %%
sns.histplot(df.INCOME,bins=10);

# %%
sns.countplot(x=df["EDUCATION"]);

# %%
sns.countplot(x=df["EDUCATION"]);

# %%
df.corr()
# Out:
#                           INDEX    INCOME  TRAVEL TIME  MILES CLOCKED  \
# INDEX                  1.000000 -0.033551     0.018497       0.040433
# INCOME                -0.033551  1.000000     0.059463       0.341234
# TRAVEL TIME            0.018497  0.059463     1.000000       0.023640
# MILES CLOCKED          0.040433  0.341234     0.023640       1.000000
# CAR AGE               -0.027206  0.264218     0.145489       0.129989
# POSTAL CODE           -0.248585  0.033428     0.019419      -0.115376
# married_Yes                 NaN       NaN          NaN            NaN
# sex_M                  0.288675  0.035156    -0.185352       0.720876
# Education_High School  0.577350 -0.118462    -0.736174       0.650742
# Education_Masters           NaN       NaN          NaN            NaN
# Education_PhD               NaN       NaN          NaN            NaN
# Job_Clerical           0.000000 -0.404197     0.170960      -0.625100
# Job_Doctor                  NaN       NaN          NaN            NaN
# Job_Home Maker              NaN       NaN          NaN            NaN
# Job_Lawyer             0.353553 -0.188143    -0.674617      -0.085897
# Job_Manager                 NaN       NaN          NaN            NaN
# Job_Professional            NaN       NaN          NaN            NaN
# Job_Student                 NaN       NaN          NaN            NaN
# Use_Private            0.000000 -0.965595    -0.765970      -0.599815
# cartype_Panel Truck    0.707107  0.633325     0.207452       0.906513
# cartype_Pickup              NaN       NaN          NaN            NaN
# cartype_SUV            0.000000 -0.404197     0.170960      -0.625100
# cartype_Sports Car    -0.288675  0.294869     0.045764      -0.210484
# cartype_Van                 NaN       NaN          NaN            NaN
# city_Houston                NaN       NaN          NaN            NaN
# city_Las Vegas              NaN       NaN          NaN            NaN
# city_Los Angeles            NaN       NaN          NaN            NaN
# city_New Albany             NaN       NaN          NaN            NaN
# city_New York City          NaN       NaN          NaN            NaN
# city_Philadelphia           NaN       NaN          NaN            NaN
# city_San Francisco          NaN       NaN          NaN            NaN
# city_Seattle                NaN       NaN          NaN            NaN
# city_Texas                  NaN       NaN          NaN            NaN
# city_Washington             NaN       NaN          NaN            NaN
#
#                         CAR AGE  POSTAL CODE  married_Yes     sex_M  \
# INDEX                 -0.027206    -0.248585          NaN  0.288675
# INCOME                 0.264218     0.033428          NaN  0.035156
# TRAVEL TIME            0.145489     0.019419          NaN -0.185352
# MILES CLOCKED          0.129989    -0.115376          NaN  0.720876
# CAR AGE                1.000000    -0.100512          NaN -0.095173
# POSTAL CODE           -0.100512     1.000000          NaN       NaN
# married_Yes                 NaN          NaN          NaN       NaN
# sex_M                 -0.095173          NaN          NaN  1.000000
# Education_High School  0.380693          NaN          NaN  0.666667
# Education_Masters           NaN          NaN          NaN       NaN
# Education_PhD               NaN          NaN          NaN       NaN
# Job_Clerical          -0.582816          NaN          NaN -0.408248
# Job_Doctor                  NaN          NaN          NaN       NaN
# Job_Home Maker              NaN          NaN          NaN       NaN
# Job_Lawyer             0.582816          NaN          NaN -0.408248
# Job_Manager                 NaN          NaN          NaN       NaN
# Job_Professional            NaN          NaN          NaN       NaN
# Job_Student                 NaN          NaN          NaN       NaN
# Use_Private           -0.475867          NaN          NaN -0.166667
# cartype_Panel Truck    0.466252          NaN          NaN  0.612372
# cartype_Pickup              NaN          NaN          NaN       NaN
# cartype_SUV           -0.582816          NaN          NaN -0.408248
# cartype_Sports Car     0.571040          NaN          NaN -0.666667
# cartype_Van                 NaN          NaN          NaN       NaN
# city_Houston                NaN          NaN          NaN       NaN
# city_Las Vegas              NaN          NaN          NaN       NaN
# city_Los Angeles            NaN          NaN          NaN       NaN
# city_New Albany             NaN          NaN          NaN       NaN
# city_New York City          NaN          NaN          NaN       NaN
# city_Philadelphia           NaN          NaN          NaN       NaN
# city_San Francisco          NaN          NaN          NaN       NaN
# city_Seattle                NaN          NaN          NaN       NaN
# city_Texas                  NaN          NaN          NaN       NaN
# city_Washington             NaN          NaN          NaN       NaN
#
#                        Education_High School  Education_Masters  ...  \
# INDEX                               0.577350                NaN  ...
# INCOME                             -0.118462                NaN  ...
# TRAVEL TIME                        -0.736174                NaN  ...
# MILES CLOCKED                       0.650742                NaN  ...
# CAR AGE                             0.380693                NaN  ...
# POSTAL CODE                              NaN                NaN  ...
# married_Yes                              NaN                NaN  ...
# sex_M                               0.666667                NaN  ...
# Education_High School               1.000000                NaN  ...
# Education_Masters                        NaN                NaN  ...
# Education_PhD                            NaN                NaN  ...
# Job_Clerical                       -0.612372                NaN  ...
# Job_Doctor                               NaN                NaN  ...
# Job_Home Maker                           NaN                NaN  ...
# Job_Lawyer                          0.408248                NaN  ...
# Job_Manager                              NaN                NaN  ...
# Job_Professional                         NaN                NaN  ...
# Job_Student                              NaN                NaN  ...
# Use_Private                         0.166667                NaN  ...
# cartype_Panel Truck                 0.408248                NaN  ...
# cartype_Pickup                           NaN                NaN  ...
# cartype_SUV                        -0.612372                NaN  ...
# cartype_Sports Car                 -0.166667                NaN  ...
# cartype_Van                              NaN                NaN  ...
# city_Houston                             NaN                NaN  ...
# city_Las Vegas                           NaN                NaN  ...
# city_Los Angeles                         NaN                NaN  ...
# city_New Albany                          NaN                NaN  ...
# city_New York City                       NaN                NaN  ...
# city_Philadelphia                        NaN                NaN  ...
# city_San Francisco                       NaN                NaN  ...
# city_Seattle                             NaN                NaN  ...
# city_Texas                               NaN                NaN  ...
# city_Washington                          NaN                NaN  ...
#
#                        city_Houston  city_Las Vegas  city_Los Angeles  \
# INDEX                           NaN             NaN               NaN
# INCOME                          NaN             NaN               NaN
# TRAVEL TIME                     NaN             NaN               NaN
# MILES CLOCKED                   NaN             NaN               NaN
# CAR AGE                         NaN             NaN               NaN
# POSTAL CODE                     NaN             NaN               NaN
# married_Yes                     NaN             NaN               NaN
# sex_M                           NaN             NaN               NaN
# Education_High School           NaN             NaN               NaN
# Education_Masters               NaN             NaN               NaN
# Education_PhD                   NaN             NaN               NaN
# Job_Clerical                    NaN             NaN               NaN
# Job_Doctor                      NaN             NaN               NaN
# Job_Home Maker                  NaN             NaN               NaN
# Job_Lawyer                      NaN             NaN               NaN
# Job_Manager                     NaN             NaN               NaN
# Job_Professional                NaN             NaN               NaN
# Job_Student                     NaN             NaN               NaN
# Use_Private                     NaN             NaN               NaN
# cartype_Panel Truck             NaN             NaN               NaN
# cartype_Pickup                  NaN             NaN               NaN
# cartype_SUV                     NaN             NaN               NaN
# cartype_Sports Car              NaN             NaN               NaN
# cartype_Van                     NaN             NaN               NaN
# city_Houston                    NaN             NaN               NaN
# city_Las Vegas                  NaN             NaN               NaN
# city_Los Angeles                NaN             NaN               NaN
# city_New Albany                 NaN             NaN               NaN
# city_New York City              NaN             NaN               NaN
# city_Philadelphia               NaN             NaN               NaN
# city_San Francisco              NaN             NaN               NaN
# city_Seattle                    NaN             NaN               NaN
# city_Texas                      NaN             NaN               NaN
# city_Washington                 NaN             NaN               NaN
#
#                        city_New Albany  city_New York City  city_Philadelphia  \
# INDEX                              NaN                 NaN                NaN
# INCOME                             NaN                 NaN                NaN
# TRAVEL TIME                        NaN                 NaN                NaN
# MILES CLOCKED                      NaN                 NaN                NaN
# CAR AGE                            NaN                 NaN                NaN
# POSTAL CODE                        NaN                 NaN                NaN
# married_Yes                        NaN                 NaN                NaN
# sex_M                              NaN                 NaN                NaN
# Education_High School              NaN                 NaN                NaN
# Education_Masters                  NaN                 NaN                NaN
# Education_PhD                      NaN                 NaN                NaN
# Job_Clerical                       NaN                 NaN                NaN
# Job_Doctor                         NaN                 NaN                NaN
# Job_Home Maker                     NaN                 NaN                NaN
# Job_Lawyer                         NaN                 NaN                NaN
# Job_Manager                        NaN                 NaN                NaN
# Job_Professional                   NaN                 NaN                NaN
# Job_Student                        NaN                 NaN                NaN
# Use_Private                        NaN                 NaN                NaN
# cartype_Panel Truck                NaN                 NaN                NaN
# cartype_Pickup                     NaN                 NaN                NaN
# cartype_SUV                        NaN                 NaN                NaN
# cartype_Sports Car                 NaN                 NaN                NaN
# cartype_Van                        NaN                 NaN                NaN
# city_Houston                       NaN                 NaN                NaN
# city_Las Vegas                     NaN                 NaN                NaN
# city_Los Angeles                   NaN                 NaN                NaN
# city_New Albany                    NaN                 NaN                NaN
# city_New York City                 NaN                 NaN                NaN
# city_Philadelphia                  NaN                 NaN                NaN
# city_San Francisco                 NaN                 NaN                NaN
# city_Seattle                       NaN                 NaN                NaN
# city_Texas                         NaN                 NaN                NaN
# city_Washington                    NaN                 NaN                NaN
#
#                        city_San Francisco  city_Seattle  city_Texas  \
# INDEX                                 NaN           NaN         NaN
# INCOME                                NaN           NaN         NaN
# TRAVEL TIME                           NaN           NaN         NaN
# MILES CLOCKED                         NaN           NaN         NaN
# CAR AGE                               NaN           NaN         NaN
# POSTAL CODE                           NaN           NaN         NaN
# married_Yes                           NaN           NaN         NaN
# sex_M                                 NaN           NaN         NaN
# Education_High School                 NaN           NaN         NaN
# Education_Masters                     NaN           NaN         NaN
# Education_PhD                         NaN           NaN         NaN
# Job_Clerical                          NaN           NaN         NaN
# Job_Doctor                            NaN           NaN         NaN
# Job_Home Maker                        NaN           NaN         NaN
# Job_Lawyer                            NaN           NaN         NaN
# Job_Manager                           NaN           NaN         NaN
# Job_Professional                      NaN           NaN         NaN
# Job_Student                           NaN           NaN         NaN
# Use_Private                           NaN           NaN         NaN
# cartype_Panel Truck                   NaN           NaN         NaN
# cartype_Pickup                        NaN           NaN         NaN
# cartype_SUV                           NaN           NaN         NaN
# cartype_Sports Car                    NaN           NaN         NaN
# cartype_Van                           NaN           NaN         NaN
# city_Houston                          NaN           NaN         NaN
# city_Las Vegas                        NaN           NaN         NaN
# city_Los Angeles                      NaN           NaN         NaN
# city_New Albany                       NaN           NaN         NaN
# city_New York City                    NaN           NaN         NaN
# city_Philadelphia                     NaN           NaN         NaN
# city_San Francisco                    NaN           NaN         NaN
# city_Seattle                          NaN           NaN         NaN
# city_Texas                            NaN           NaN         NaN
# city_Washington                       NaN           NaN         NaN
#
#                        city_Washington
# INDEX                              NaN
# INCOME                             NaN
# TRAVEL TIME                        NaN
# MILES CLOCKED                      NaN
# CAR AGE                            NaN
# POSTAL CODE                        NaN
# married_Yes                        NaN
# sex_M                              NaN
# Education_High School              NaN
# Education_Masters                  NaN
# Education_PhD                      NaN
# Job_Clerical                       NaN
# Job_Doctor                         NaN
# Job_Home Maker                     NaN
# Job_Lawyer                         NaN
# Job_Manager                        NaN
# Job_Professional                   NaN
# Job_Student                        NaN
# Use_Private                        NaN
# cartype_Panel Truck                NaN
# cartype_Pickup                     NaN
# cartype_SUV                        NaN
# cartype_Sports Car                 NaN
# cartype_Van                        NaN
# city_Houston                       NaN
# city_Las Vegas                     NaN
# city_Los Angeles                   NaN
# city_New Albany                    NaN
# city_New York City                 NaN
# city_Philadelphia                  NaN
# city_San Francisco                 NaN
# city_Seattle                       NaN
# city_Texas                         NaN
# city_Washington                    NaN
#
# [34 rows x 34 columns]

# %% [markdown]
# ##Correlation Heatmap

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.show()

# %%
#Scales the data. Essentially returns the z-scores of every attribute
from sklearn.preprocessing import StandardScaler
std_scale = StandardScaler()
std_scale
# Out:
# StandardScaler()

# %%
StandardScaler()
# Out:
# StandardScaler()

# %%
df['INCOME'] = std_scale.fit_transform(df[['INCOME']])
df['TRAVEL TIME'] = std_scale.fit_transform(df[['TRAVEL TIME']])
df['CAR AGE'] = std_scale.fit_transform(df[['CAR AGE']])
df['MILES CLOCKED']= std_scale.fit_transform(df[['MILES CLOCKED']])

# %%
df.head()
# Out:
#    INDEX    INCOME MARITAL STATUS SEX    EDUCATION          JOB  TRAVEL TIME  \
# 0      1  2.186892             No   F    Bachelors  Blue Collar     0.813273
# 1      2  0.108850             No   M  High School  Blue Collar    -0.981463
# 2      3  0.448162             No   F    Bachelors     Clerical    -0.048886
# 3      4  0.842148             No   F  High School       Lawyer    -1.351394
# 4      5  2.340148             No   M  High School  Blue Collar     0.007325
#
#           USE  MILES CLOCKED     CAR TYPE   CAR AGE   CITY POSTAL CODE
# 0  Commercial       0.529946   Sports Car  0.137267  Texas     42420.0
# 1     Private       0.748411      Minivan -1.052842  Texas     42420.0
# 2     Private      -0.137830          SUV -1.052842  Texas     42420.0
# 3     Private       0.656656   Sports Car  0.930674  Texas     42420.0
# 4  Commercial       2.118917  Panel Truck  0.732322  Texas     42420.0

# %% [markdown]
# ##ENCODING

# %%
dummies=pd.get_dummies(df[["MARITAL STATUS", "SEX","EDUCATION","JOB","USE","CAR TYPE","CITY"]], columns=["MARITAL STATUS", "SEX","EDUCATION","JOB","USE","CAR TYPE","CITY"], prefix=["married", "sex","Education","Job","Use","cartype","city"],drop_first=True).head()
dummies.head(10)
# Out:
#    married_Yes  sex_M  Education_High School  Education_Masters  \
# 0        False  False                  False              False
# 1        False   True                   True              False
# 2        False  False                  False              False
# 3        False  False                   True              False
# 4        False   True                   True              False
#
#    Education_PhD  Job_Clerical  Job_Doctor  Job_Home Maker  Job_Lawyer  \
# 0          False         False       False           False       False
# 1          False         False       False           False       False
# 2          False          True       False           False       False
# 3          False         False       False           False        True
# 4          False         False       False           False       False
#
#    Job_Manager  ...  city_Houston  city_Las Vegas  city_Los Angeles  \
# 0        False  ...         False           False             False
# 1        False  ...         False           False             False
# 2        False  ...         False           False             False
# 3        False  ...         False           False             False
# 4        False  ...         False           False             False
#
#    city_New Albany  city_New York City  city_Philadelphia  city_San Francisco  \
# 0            False               False              False               False
# 1            False               False              False               False
# 2            False               False              False               False
# 3            False               False              False               False
# 4            False               False              False               False
#
#    city_Seattle  city_Texas  city_Washington
# 0         False        True            False
# 1         False        True            False
# 2         False        True            False
# 3         False        True            False
# 4         False        True            False
#
# [5 rows x 28 columns]

# %%
columns=["MARITAL STATUS", "SEX","EDUCATION","JOB","USE","CAR TYPE","CITY"]
df = pd.concat([df, dummies], axis=1)
df.drop(columns, axis = 1, inplace=True)

# %%
df.head()
# Out:
#    INDEX    INCOME  TRAVEL TIME  MILES CLOCKED   CAR AGE POSTAL CODE  \
# 0      1  2.186892     0.813273       0.529946  0.137267     42420.0
# 1      2  0.108850    -0.981463       0.748411 -1.052842     42420.0
# 2      3  0.448162    -0.048886      -0.137830 -1.052842     42420.0
# 3      4  0.842148    -1.351394       0.656656  0.930674     42420.0
# 4      5  2.340148     0.007325       2.118917  0.732322     42420.0
#
#   married_Yes  sex_M Education_High School Education_Masters  ...  \
# 0       False  False                 False             False  ...
# 1       False   True                  True             False  ...
# 2       False  False                 False             False  ...
# 3       False  False                  True             False  ...
# 4       False   True                  True             False  ...
#
#   city_Houston city_Las Vegas city_Los Angeles city_New Albany  \
# 0        False          False            False           False
# 1        False          False            False           False
# 2        False          False            False           False
# 3        False          False            False           False
# 4        False          False            False           False
#
#   city_New York City city_Philadelphia city_San Francisco city_Seattle  \
# 0              False             False              False        False
# 1              False             False              False        False
# 2              False             False              False        False
# 3              False             False              False        False
# 4              False             False              False        False
#
#   city_Texas city_Washington
# 0       True           False
# 1       True           False
# 2       True           False
# 3       True           False
# 4       True           False
#
# [5 rows x 34 columns]

# %% [markdown]
# # Selection Techniques

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, f_regression, chi2
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
data = pd.read_csv('data (2).csv')

# %%
print("Data Head:\n", data.head())
print("Data Info:\n", data.info())
# Out:
# Data Head:
#     feature1  feature2  feature3     target
# 0 -0.570563  1.420342  0.495580  -9.763182
# 1 -0.990563  0.556965  1.045064 -24.029355
# 2 -0.674728  0.150617  1.774645  45.616421
# 3  0.388250 -0.387127 -0.110229  34.135737
# 4  1.167882 -0.024104  0.145063  86.663647
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   feature1  200 non-null    float64
#  1   feature2  200 non-null    float64
#  2   feature3  200 non-null    float64
#  3   target    200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# Data Info:
#  None

# %%
target_column = 'target'  # Replace with the actual target column name
X = data.drop(target_column, axis=1)
y = data[target_column]

# %%
label_encoder = LabelEncoder()
for col in X.select_dtypes(include=['object']).columns:
    X[col] = label_encoder.fit_transform(X[col])

# %%
X_non_negative = StandardScaler().fit_transform(X)
X_non_negative = np.abs(X_non_negative)

# %%
correlation_matrix = X.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
f_test = SelectKBest(score_func=f_regression, k='all')
f_test.fit(X, y)
# Out:
# SelectKBest(k='all', score_func=<function f_regression at 0x79df3c37e950>)

# %%
f_scores = pd.DataFrame({'Feature': X.columns, 'F-Score': f_test.scores_})
f_scores = f_scores.sort_values(by='F-Score', ascending=False)
print("\nF-Regression Scores:\n", f_scores)
# Out:
# F-Regression Scores:
#      Feature     F-Score
# 0  feature1  403.164147
# 2  feature3   99.408150
# 1  feature2    0.193764

# %%
y_binned = pd.cut(y, bins=3, labels=[0, 1, 2])

# %%
chi2_test = SelectKBest(score_func=chi2, k='all')
chi2_test.fit(X_non_negative, y_binned)
# Out:
# SelectKBest(k='all', score_func=<function chi2 at 0x79df3c37e710>)

# %%
chi2_scores = pd.DataFrame({'Feature': X.columns, 'Chi-Square Score': chi2_test.scores_})
chi2_scores = chi2_scores.sort_values(by='Chi-Square Score', ascending=False)
print("\nChi-Square Scores:\n", chi2_scores)
# Out:
# Chi-Square Scores:
#      Feature  Chi-Square Score
# 0  feature1         25.274161
# 2  feature3          3.588795
# 1  feature2          0.014106

# %%
feature_selection_summary = pd.merge(f_scores, chi2_scores, on='Feature', how='inner')
print("\nFeature Selection Summary:\n", feature_selection_summary)
# Out:
# Feature Selection Summary:
#      Feature     F-Score  Chi-Square Score
# 0  feature1  403.164147         25.274161
# 1  feature3   99.408150          3.588795
# 2  feature2    0.193764          0.014106
